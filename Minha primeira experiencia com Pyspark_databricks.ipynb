# %% [markdown]
# # Meu primeiro topico

# %%
# %sql
list '/Volumes/coderhouse_ds_58690/default/dados_manuais/base_excel/'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
a= 30
b=60
print (a*b)
# Out:
# 1800

# %%
variavel = 'vanessa'
print(variavel * 3)
# Out:
# vanessavanessavanessa

# %%
from datetime import datetime

current_datetime = datetime.now()
display(current_datetime)
# Out:
# datetime.datetime(2024, 7, 25, 23, 56, 9, 701398)

# %%
# %sql
use catalog `ultraflow_sql_db`;
select
  *
from
  `suprimentos`.`fpedidoscompras`
limit
  100;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
type(_sqldf)
# Out:
# pyspark.sql.connect.dataframe.DataFrame

# %%
_sqldf.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # bem aqui estou usando pyspark

# %%
_sqldf_filtered = _sqldf.filter(_sqldf.LOCAL_CORRIGIDO == "0101")
display(_sqldf_filtered)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
